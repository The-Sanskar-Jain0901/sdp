# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.layers import Flatten, Dense
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator , img_to_array, load_img
from keras.applications.mobilenet import MobileNet, preprocess_input 
from keras.losses import categorical_crossentropy

# %% [markdown]
# #  Building  Model To train the data

# %%
# Working with pre trained model 

base_model = MobileNet( input_shape=(224,224,3), include_top= False )

for layer in base_model.layers:
  layer.trainable = False


x = Flatten()(base_model.output)
x = Dense(units=7 , activation='softmax' )(x)

# creating our model.
model = Model(base_model.input, x)

# %%
model.compile(optimizer='adam', loss= categorical_crossentropy , metrics=['accuracy']  )

# %% [markdown]
# # Preparing our data using data generator

# %%
train_datagen = ImageDataGenerator(
     zoom_range = 0.2, 
     shear_range = 0.2, 
     horizontal_flip=True, 
     rescale = 1./255
)

train_data = train_datagen.flow_from_directory(directory= "D:/Train", 
                                               target_size=(224,224), 
                                               batch_size=32,
                                  )


train_data.class_indices
# Out:
# Found 318 images belonging to 7 classes.
# {'Angry': 0,
#  'Disguist': 1,
#  'Fear': 2,
#  'Happy': 3,
#  'Neutral': 4,
#  'Sad': 5,
#  'Surprise': 6}

# %%
val_datagen = ImageDataGenerator(rescale = 1./255 )

val_data = val_datagen.flow_from_directory(directory= "D:\Train", 
                                           target_size=(224,224), 
                                           batch_size=32,
                                  )
# Out:
# Found 318 images belonging to 7 classes.

# %% [markdown]
# # visualizaing the data that is fed to train data gen

# %%
# to visualize the images in the traing data denerator 

t_img , label = train_data.next()

#-----------------------------------------------------------------------------
# function when called will prot the images 
def plotImages(img_arr, label):
  """
  input  :- images array 
  output :- plots the images 
  """
  count = 0
  for im, l in zip(img_arr,label) :
    plt.imshow(im)
    plt.title(im.shape)
    plt.axis = False
    plt.show()
    
    count += 1
    if count == 10:
      break

#-----------------------------------------------------------------------------
# function call to plot the images 
plotImages(t_img, label)

# %% [markdown]
# # having early stopping and model check point

# %%
## having early stopping and model check point 

from keras.callbacks import ModelCheckpoint, EarlyStopping

# early stopping
es = EarlyStopping(monitor='val_accuracy', min_delta= 0.01 , patience= 5, verbose= 1, mode='auto')

# model check point
mc = ModelCheckpoint(filepath="bestModel.h5", monitor= 'val_accuracy', verbose= 1, save_best_only= True, mode = 'auto')

# puting call back in a list 
call_back = [es, mc]

# %%
hist = model.fit_generator(train_data, 
                           steps_per_epoch= 10, 
                           epochs= 30, 
                           validation_data= val_data, 
                           validation_steps= 8, 
                           callbacks=[es,mc])
# Out:
# C:\Users\sansk\AppData\Local\Temp/ipykernel_5684/564963302.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model.fit_generator(train_data,
# Epoch 1/30
# 10/10 [==============================] - ETA: 0s - loss: 8.7073 - accuracy: 0.2358
# Epoch 00001: val_accuracy improved from -inf to 0.58594, saving model to bestModel.h5
# 10/10 [==============================] - 13s 1s/step - loss: 8.7073 - accuracy: 0.2358 - val_loss: 3.2504 - val_accuracy: 0.5859
# Epoch 2/30
# 10/10 [==============================] - ETA: 0s - loss: 3.3257 - accuracy: 0.5692
# Epoch 00002: val_accuracy improved from 0.58594 to 0.75391, saving model to bestModel.h5
# 10/10 [==============================] - 9s 879ms/step - loss: 3.3257 - accuracy: 0.5692 - val_loss: 1.7566 - val_accuracy: 0.7539
# Epoch 3/30
# 10/10 [==============================] - ETA: 0s - loss: 1.4289 - accuracy: 0.7358
# Epoch 00003: val_accuracy improved from 0.75391 to 0.89062, saving model to bestModel.h5
# 10/10 [==============================] - 9s 873ms/step - loss: 1.4289 - accuracy: 0.7358 - val_loss: 0.4699 - val_accuracy: 0.8906
# Epoch 4/30
# 10/10 [==============================] - ETA: 0s - loss: 0.9307 - accuracy: 0.8396
# Epoch 00004: val_accuracy improved from 0.89062 to 0.91016, saving model to bestModel.h5
# 10/10 [==============================] - 9s 875ms/step - loss: 0.9307 - accuracy: 0.8396 - val_loss: 0.3671 - val_accuracy: 0.9102
# Epoch 5/30
# 10/10 [==============================] - ETA: 0s - loss: 0.5674 - accuracy: 0.9057
# Epoch 00005: val_accuracy improved from 0.91016 to 0.93359, saving model to bestModel.h5
# 10/10 [==============================] - 9s 919ms/step - loss: 0.5674 - accuracy: 0.9057 - val_loss: 0.2645 - val_accuracy: 0.9336
# Epoch 6/30
# 10/10 [==============================] - ETA: 0s - loss: 0.3662 - accuracy: 0.9088
# Epoch 00006: val_accuracy improved from 0.93359 to 0.96094, saving model to bestModel.h5
# 10/10 [==============================] - 9s 966ms/step - loss: 0.3662 - accuracy: 0.9088 - val_loss: 0.1418 - val_accuracy: 0.9609
# Epoch 7/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1634 - accuracy: 0.9528
# Epoch 00007: val_accuracy improved from 0.96094 to 0.98828, saving model to bestModel.h5
# 10/10 [==============================] - 10s 975ms/step - loss: 0.1634 - accuracy: 0.9528 - val_loss: 0.0240 - val_accuracy: 0.9883
# Epoch 8/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1307 - accuracy: 0.9780
# Epoch 00008: val_accuracy improved from 0.98828 to 0.99609, saving model to bestModel.h5
# 10/10 [==============================] - 10s 983ms/step - loss: 0.1307 - accuracy: 0.9780 - val_loss: 0.0095 - val_accuracy: 0.9961
# Epoch 9/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0648 - accuracy: 0.9811
# Epoch 00009: val_accuracy did not improve from 0.99609
# 10/10 [==============================] - 9s 910ms/step - loss: 0.0648 - accuracy: 0.9811 - val_loss: 0.0105 - val_accuracy: 0.9961
# Epoch 10/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0920 - accuracy: 0.9780
# Epoch 00010: val_accuracy improved from 0.99609 to 1.00000, saving model to bestModel.h5
# 10/10 [==============================] - 9s 952ms/step - loss: 0.0920 - accuracy: 0.9780 - val_loss: 2.9756e-04 - val_accuracy: 1.0000
# Epoch 11/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0259 - accuracy: 0.9906
# Epoch 00011: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 9s 906ms/step - loss: 0.0259 - accuracy: 0.9906 - val_loss: 0.0333 - val_accuracy: 0.9883
# Epoch 12/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0324 - accuracy: 0.9937
# Epoch 00012: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 9s 903ms/step - loss: 0.0324 - accuracy: 0.9937 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 13/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1164 - accuracy: 0.9780
# Epoch 00013: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 9s 897ms/step - loss: 0.1164 - accuracy: 0.9780 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 14/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1077 - accuracy: 0.9811
# Epoch 00014: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 9s 926ms/step - loss: 0.1077 - accuracy: 0.9811 - val_loss: 0.0089 - val_accuracy: 0.9961
# Epoch 15/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0387 - accuracy: 0.9874
# Epoch 00015: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 9s 901ms/step - loss: 0.0387 - accuracy: 0.9874 - val_loss: 2.0442e-04 - val_accuracy: 1.0000
# Epoch 00015: early stopping

# %%
h =  hist.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'] , c = "red")
plt.title("acc vs v-acc")
plt.show()

# %%
plt.plot(h['loss'])
plt.plot(h['val_loss'] , c = "red")
plt.title("loss vs v-loss")
plt.show()
